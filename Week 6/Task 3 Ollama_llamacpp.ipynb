# %%
# !pip install llama-cpp-python
# Out:
# ^C
# ...
#      ---------------------------------------- 0.0/49.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/49.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/49.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/49.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/49.8 MB 131.3 kB/s eta 0:06:19
#      --------------------------------------- 0.0/49.8 MB 146.3 kB/s eta 0:05:40
#      --------------------------------------- 0.0/49.8 MB 164.3 kB/s eta 0:05:03
#      --------------------------------------- 0.1/49.8 MB 204.8 kB/s eta 0:04:03
#      --------------------------------------- 0.1/49.8 MB 345.9 kB/s eta 0:02:24
#      --------------------------------------- 0.1/49.8 MB 343.4 kB/s eta 0:02:25
#      --------------------------------------- 0.2/49.8 MB 554.9 kB/s eta 0:01:30
#      --------------------------------------- 0.3/49.8 MB 655.5 kB/s eta 0:01:16
# ...

# %%
llama-cli --help

# %%
import os
import subprocess

# Add MinGW64 bin to PATH for this notebook cell
os.environ["PATH"] += r";C:\msys64\mingw64\bin"

output = subprocess.run([
    r"C:\Debi\AlgoCas\Week 6\llama.cpp\build\bin\llama-run.exe",
    r"..\models\Llama-3.2-3B-Instruct-Q8_0.gguf",
    "Write a short welcome message for a product design onboarding tool."
], capture_output=True, text=True)

print(output.stdout)
print(output.stderr)

# %%
output
# Out:
# CompletedProcess(args=['C:\\Debi\\AlgoCas\\Week 6\\llama.cpp\\build\\bin\\llama-run.exe', '..\\models\\Llama-3.2-3B-Instruct-Q8_0.gguf', 'Write a short welcome message for a product design onboarding tool.'], returncode=3221225785, stdout='', stderr='')
